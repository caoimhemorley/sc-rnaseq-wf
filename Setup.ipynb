# %% [markdown]
# # setup testing

# %%
from pathlib import Path
import pandas as pd

# %% [markdown]
# ## copy datasets

# %%
WORKSPACE_PATH = Path.home() / "workspace"
data_bucket = WORKSPACE_PATH / "01_PMDBS_scRNAseq_Datasets/"

dataset_name = "asap-curated-cohort-pmdbs-sc-rnaseq"
datasets_path = data_bucket / f"{dataset_name}"

team_name = "asap-cohort"
dataset_path = datasets_path / f"pmdbs_sc_rnaseq/cohort_analysis/{team_name}.merged_adata_object.h5ad"

# %%
local_path = WORKSPACE_PATH / "data/testing/"

f"cp {dataset_path} {local_path}/"
# Out:
# 'cp /home/jupyter/workspace/01_PMDBS_scRNAseq_Datasets/asap-curated-cohort-pmdbs-sc-rnaseq/pmdbs_sc_rnaseq/cohort_analysis/asap-cohort.merged_adata_object.h5ad /home/jupyter/workspace/data/testing/'

# %%
dataset_name = "asap-curated-team-hardy-pmdbs-sn-rnaseq"
datasets_path = data_bucket / f"{dataset_name}"

team_name = "team-hardy"
dataset_path = datasets_path / f"pmdbs_sc_rnaseq/cohort_analysis/{team_name}.merged_adata_object.h5ad"

f"cp {dataset_path} {local_path}/"
# Out:
# 'cp /home/jupyter/workspace/01_PMDBS_scRNAseq_Datasets/asap-curated-team-hardy-pmdbs-sn-rnaseq/pmdbs_sc_rnaseq/cohort_analysis/team-hardy.merged_adata_object.h5ad /home/jupyter/workspace/data/testing/'

# %% [markdown]
# ## create environment

# %%
repo_path = Path.home() / "repos"
script_path = repo_path / "pmdbs-sc-rnaseq-wf/docker/scvi/scripts/main"

# %%
# sudo ln -s /home/jupyter/repos/pmdbs-sc-rnaseq-wf/docker/scvi/scripts /opt/scripts
f"{script_path.parent} /opt/scripts"
# Out:
# '/home/jupyter/repos/pmdbs-sc-rnaseq-wf/docker/scvi/scripts /opt/scripts'

# %% [markdown]
# RUN ln -s /opt/Python-${PYTHON3_VERSION}/python /opt/Python-${PYTHON3_VERSION}/python3
#
# COPY ./requirements.txt /opt/requirements.txt
# RUN python3 -m pip install -r /opt/requirements.txt
#
# # CUDA-enabled jaxlib is needed
# RUN python3 -m pip install --upgrade "jax[cuda12_pip]==${JAX_VERSION}" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
#
# pip install git+https://github.com/AllenInstitute/cell_type_mapper.git
#
# conda create -n test3 python=3.12 pip
#
# pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
#
# pip install --upgrade "jax[cuda11]" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# pip install scvi-tools scikit-image scikit-learn scikit-misc seaborn anndata muon tables pyarrow fastparquet igraph scib-metrics harmonypy
# pip install git+https://github.com/AllenInstitute/cell_type_mapper.git
#
# python3 -m pip install --upgrade "jax[cuda11_pip]==0.4.9" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
#
# # conda install -c conda-forge faiss-gpu # this could be the memory leak...
#
# # replace leidenalg with igraph
#
#
# # pip install --upgrade "jax[cuda12_pip]==${JAX_VERSION}" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
#
# pip install git+https://github.com/AllenInstitute/cell_type_mapper.git

# %% [markdown]
# conda create -n testing python=3.12 pip
# conda activate testing

# %% [markdown]
# pip install scvi-tools scikit-image scikit-learn scikit-misc seaborn anndata muon tables pyarrow fastparquet igraph scib-metrics harmonypy
#
# # maybe do this first?
# pip install git+https://github.com/AllenInstitute/cell_type_mapper.git
# <!-- Installing collected packages: scipy, pluggy, marshmallow, iniconfig, execnet, pytest, argschema, pytest-xdist, cell_type_mapper
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.0
#     Uninstalling scipy-1.16.0:
#       Successfully uninstalled scipy-1.16.0
# Successfully installed argschema-3.0.4 cell_type_mapper-1.5.2 execnet-2.1.1 iniconfig-2.1.0 marshmallow-3.12.2 pluggy-1.6.0 pytest-8.4.1 pytest-xdist-3.7.0 scipy-1.14.1 -->

# %% [markdown]
# pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu128

# %% [markdown]
# # NVIDIA CUDA 12 installation
# # Note: wheels only available on linux.
# pip install --upgrade "jax[cuda12]"

# %% [markdown]
# ## run workflows

# %%
script_path = Path.home() /

# %% [markdown]
# ## test outputs

# %% [markdown]
# ## confirm artifacts
#
# - list files
# - call out renames
